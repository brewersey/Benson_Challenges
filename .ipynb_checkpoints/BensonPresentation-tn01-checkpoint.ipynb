# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas as pd
import os
dir1 = r'/Users/walterkerr/metis/sf17_ds6/week1/Benson_Presentation/Benson_Challenges'
for files in os.walk(dir1):
    for file in files:
        print(file)
        #filenames += [file]
        
filenames = ['turnstile_150704.txt', 'turnstile_150711.txt', 'turnstile_150718.txt', 'turnstile_150725.txt', 'turnstile_151003.txt', 'turnstile_151010.txt', 'turnstile_151017.txt', 'turnstile_151024.txt', 'turnstile_151031.txt', 'turnstile_160702.txt', 'turnstile_160709.txt', 'turnstile_160716.txt', 'turnstile_160723.txt', 'turnstile_160730.txt', 'turnstile_161001.txt', 'turnstile_161008.txt', 'turnstile_161015.txt', 'turnstile_161022.txt', 'turnstile_161029.txt']
for fn in filenames:
    temp = pd.read_csv(fn)
    try:
        turn = turn.append(temp)
    except:
        turn = temp.copy()
turn = turn.reset_index()

# %%
turn
# Out:
#           index    C/A  UNIT       SCP        STATION LINENAME DIVISION  \
# 0             0   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 1             1   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 2             2   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 3             3   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 4             4   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 5             5   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 6             6   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 7             7   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 8             8   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 9             9   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 10           10   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 11           11   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 12           12   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 13           13   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 14           14   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 15           15   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 16           16   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 17           17   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 18           18   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 19           19   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 20           20   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 21           21   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 22           22   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 23           23   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 24           24   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 25           25   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 26           26   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 27           27   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 28           28   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# 29           29   A002  R051  02-00-00  LEXINGTON AVE   NQR456      BMT
# ...         ...    ...   ...       ...            ...      ...      ...
# 3663973  192485  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663974  192486  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663975  192487  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663976  192488  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663977  192489  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663978  192490  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663979  192491  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663980  192492  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663981  192493  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663982  192494  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663983  192495  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663984  192496  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663985  192497  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663986  192498  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663987  192499  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663988  192500  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663989  192501  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663990  192502  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663991  192503  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663992  192504  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663993  192505  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663994  192506  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663995  192507  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663996  192508  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663997  192509  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663998  192510  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3663999  192511  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3664000  192512  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3664001  192513  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
# 3664002  192514  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT
#
#                DATE      TIME     DESC  ENTRIES  \
# 0        06/27/2015  00:00:00  REGULAR  5203784
# 1        06/27/2015  04:00:00  REGULAR  5203840
# 2        06/27/2015  08:00:00  REGULAR  5203860
# 3        06/27/2015  12:00:00  REGULAR  5203987
# 4        06/27/2015  16:00:00  REGULAR  5204270
# 5        06/27/2015  20:00:00  REGULAR  5204563
# 6        06/28/2015  00:00:00  REGULAR  5204723
# 7        06/28/2015  04:00:00  REGULAR  5204748
# 8        06/28/2015  08:00:00  REGULAR  5204757
# 9        06/28/2015  12:00:00  REGULAR  5204849
# 10       06/28/2015  16:00:00  REGULAR  5205099
# 11       06/28/2015  20:00:00  REGULAR  5205422
# 12       06/29/2015  00:00:00  REGULAR  5205523
# 13       06/29/2015  04:00:00  REGULAR  5205535
# 14       06/29/2015  08:00:00  REGULAR  5205588
# 15       06/29/2015  12:00:00  REGULAR  5205765
# 16       06/29/2015  16:00:00  REGULAR  5206065
# 17       06/29/2015  20:00:00  REGULAR  5207031
# 18       06/30/2015  00:00:00  REGULAR  5207275
# 19       06/30/2015  04:00:00  REGULAR  5207293
# 20       06/30/2015  08:00:00  REGULAR  5207337
# 21       06/30/2015  12:00:00  REGULAR  5207514
# 22       06/30/2015  16:00:00  REGULAR  5207844
# 23       06/30/2015  20:00:00  REGULAR  5208595
# 24       07/01/2015  00:00:00  REGULAR  5208861
# 25       07/01/2015  04:00:00  REGULAR  5208891
# 26       07/01/2015  08:00:00  REGULAR  5208939
# 27       07/01/2015  12:00:00  REGULAR  5209107
# 28       07/01/2015  16:00:00  REGULAR  5209449
# 29       07/01/2015  20:00:00  REGULAR  5210385
# ...             ...       ...      ...      ...
# 3663973  10/24/2016  01:00:00  REGULAR     5554
# 3663974  10/24/2016  05:00:00  REGULAR     5554
# 3663975  10/24/2016  09:00:00  REGULAR     5554
# 3663976  10/24/2016  13:00:00  REGULAR     5554
# 3663977  10/24/2016  17:00:00  REGULAR     5554
# 3663978  10/24/2016  21:00:00  REGULAR     5554
# 3663979  10/25/2016  01:00:00  REGULAR     5554
# 3663980  10/25/2016  05:00:00  REGULAR     5554
# 3663981  10/25/2016  09:00:00  REGULAR     5554
# 3663982  10/25/2016  13:00:00  REGULAR     5554
# 3663983  10/25/2016  17:00:00  REGULAR     5554
# 3663984  10/25/2016  21:00:00  REGULAR     5554
# 3663985  10/26/2016  01:00:00  REGULAR     5554
# 3663986  10/26/2016  05:00:00  REGULAR     5554
# 3663987  10/26/2016  09:00:00  REGULAR     5554
# 3663988  10/26/2016  13:00:00  REGULAR     5554
# 3663989  10/26/2016  17:00:00  REGULAR     5554
# 3663990  10/26/2016  21:00:00  REGULAR     5554
# 3663991  10/27/2016  01:00:00  REGULAR     5554
# 3663992  10/27/2016  05:00:00  REGULAR     5554
# 3663993  10/27/2016  09:00:00  REGULAR     5554
# 3663994  10/27/2016  13:00:00  REGULAR     5554
# 3663995  10/27/2016  17:00:00  REGULAR     5554
# 3663996  10/27/2016  21:00:00  REGULAR     5554
# 3663997  10/28/2016  01:00:00  REGULAR     5554
# 3663998  10/28/2016  05:00:00  REGULAR     5554
# 3663999  10/28/2016  09:00:00  REGULAR     5554
# 3664000  10/28/2016  13:00:00  REGULAR     5554
# 3664001  10/28/2016  17:00:00  REGULAR     5554
# 3664002  10/28/2016  21:00:00  REGULAR     5554
#
#          EXITS
# 0                                                  1759879
# 1                                                  1759886
# 2                                                  1759910
# 3                                                  1759995
# 4                                                  1760060
# 5                                                  1760125
# 6                                                  1760168
# 7                                                  1760170
# 8                                                  1760188
# 9                                                  1760240
# 10                                                 1760293
# 11                                                 1760355
# 12                                                 1760367
# 13                                                 1760375
# 14                                                 1760457
# 15                                                 1760710
# 16                                                 1760776
# 17                                                 1760830
# 18                                                 1760871
# 19                                                 1760874
# 20                                                 1760968
# 21                                                 1761263
# 22                                                 1761345
# 23                                                 1761754
# 24                                                 1761776
# 25                                                 1761784
# 26                                                 1761878
# 27                                                 1762159
# 28                                                 1762241
# 29                                                 1762368
# ...                                                    ...
# 3663973                                                276
# 3663974                                                276
# 3663975                                                276
# 3663976                                                276
# 3663977                                                276
# 3663978                                                276
# 3663979                                                276
# 3663980                                                276
# 3663981                                                276
# 3663982                                                276
# 3663983                                                276
# 3663984                                                276
# 3663985                                                276
# 3663986                                                276
# 3663987                                                276
# 3663988                                                276
# 3663989                                                276
# 3663990                                                276
# 3663991                                                276
# 3663992                                                276
# 3663993                                                276
# 3663994                                                276
# 3663995                                                276
# 3663996                                                276
# 3663997                                                276
# 3663998                                                276
# 3663999                                                276
# 3664000                                                276
# 3664001                                                276
# 3664002                                                276
#
# [3664003 rows x 12 columns]

# %%
stationList = turn['STATION'].unique()
stationList = list(stationList)
#stationList = stationList.sort_values()
stationList
# Out:
# ['LEXINGTON AVE',
#  '5 AVE-59 ST',
#  '57 ST-7 AVE',
#  '49 ST-7 AVE',
#  '42 ST-TIMES SQ',
#  '34 ST-HERALD SQ',
#  '28 ST-BROADWAY',
#  '23 ST-5 AVE',
#  '14 ST-UNION SQ',
#  "8 ST-B'WAY NYU",
#  "PRINCE ST-B'WAY",
#  'CANAL ST',
#  'CITY HALL',
#  'CORTLANDT ST',
#  'RECTOR ST',
#  'WHITEHALL ST',
#  'ESSEX ST',
#  'BOWERY',
#  'CHAMBERS ST',
#  'FULTON ST',
#  'BROAD ST',
#  '7 AVE',
#  'PARK PLACE',
#  'BOTANIC GARDEN',
#  'PROSPECT PARK',
#  'PARKSIDE AVE',
#  'CHURCH AVE',
#  'BEVERLEY ROAD',
#  'CORTELYOU ROAD',
#  'NEWKIRK PLAZA',
#  'AVE H',
#  'AVE J',
#  'AVE M',
#  'KINGS HIGHWAY',
#  'AVE U',
#  'NECK ROAD',
#  'SHEEPSHEAD BAY',
#  'BRIGHTON BEACH',
#  'OCEAN PARKWAY',
#  'BOROUGH HALL/CT',
#  'JAY ST-METROTEC',
#  'DEKALB AVE',
#  'BARCLAYS CENTER',
#  'UNION ST',
#  '9 ST',
#  'PROSPECT AVE',
#  '25 ST',
#  '36 ST',
#  '45 ST',
#  '53 ST',
#  '59 ST',
#  'BAY RIDGE AVE',
#  '77 ST',
#  '86 ST',
#  'BAY RIDGE-95 ST',
#  '8 AVE',
#  'FT HAMILTON PKY',
#  'NEW UTRECHT AVE',
#  '18 AVE',
#  '20 AVE',
#  'BAY PKY-22 AVE',
#  '9 AVE',
#  '50 ST',
#  '55 ST',
#  '71 ST',
#  '79 ST',
#  'BAY PARKWAY',
#  '25 AVE',
#  'BAY 50 ST',
#  'STILLWELL AVE',
#  'W 8 ST-AQUARIUM',
#  '6 AVE',
#  '3 AVE',
#  '1 AVE',
#  'BEDFORD AVE',
#  'LORIMER ST',
#  'GRAHAM AVE',
#  'GRAND ST',
#  'MONTROSE AVE',
#  'MORGAN AVE',
#  'JEFFERSON ST',
#  'MYRTLE AVE',
#  'HALSEY ST',
#  'WILSON AVE',
#  'BUSHWICK AVE',
#  'ATLANTIC AVE',
#  'SUTTER AVE',
#  'LIVONIA AVE',
#  'NEW LOTS AVE',
#  'EAST 105 ST',
#  'ROCKAWAY PKY',
#  'JFK HOWARD BCH',
#  'JFK JAMAICA CT1',
#  'MARCY AVE',
#  'HEWES ST',
#  'FLUSHING AVE',
#  'KOSCIUSZKO ST',
#  'GATES AVE',
#  'CHAUNCEY ST',
#  'ALABAMA AVE',
#  'VAN SICLEN AVE',
#  'CLEVELAND ST',
#  'NORWOOD AVE',
#  'CRESCENT ST',
#  'CYPRESS HILLS',
#  'ELDERTS LANE',
#  'FOREST PARKWAY',
#  'WOODHAVEN BLVD',
#  '104 ST',
#  '111 ST',
#  '121 ST',
#  'CENTRAL AVE',
#  'KNICKERBOCKER',
#  'SENECA AVE',
#  'FOREST AVE',
#  'FRESH POND ROAD',
#  'METROPOLITAN AV',
#  'INWOOD-207 ST',
#  'DYCKMAN-200 ST',
#  '190 ST',
#  '181 ST',
#  '175 ST',
#  '168 ST-BROADWAY',
#  '163 ST-AMSTERDM',
#  '155 ST',
#  '145 ST',
#  '135 ST',
#  '125 ST',
#  '116 ST',
#  'CATHEDRL-110 ST',
#  '103 ST',
#  '96 ST',
#  '81 ST-MUSEUM',
#  '72 ST',
#  '59 ST-COLUMBUS',
#  '42 ST-PA BUS TE',
#  '34 ST-PENN STA',
#  '23 ST',
#  '14 ST',
#  'W 4 ST-WASH SQ',
#  'SPRING ST',
#  'WORLD TRADE CTR',
#  'HIGH ST',
#  'HOYT/SCHERMER',
#  'LAFAYETTE AVE',
#  'CLINTON-WASH AV',
#  'FRANKLIN AVE',
#  'NOSTRAND AVE',
#  'KINGSTON-THROOP',
#  'UTICA AVE',
#  'RALPH AVE',
#  'ROCKAWAY AVE',
#  'BROADWAY-ENY',
#  'LIBERTY AVE',
#  'SHEPHERD AVE',
#  'EUCLID AVE',
#  'GRANT AVE',
#  'HUDSON-80 ST',
#  'BOYD-88 ST',
#  'ROCKAWAY BLVD',
#  'OXFORD-104 ST',
#  'GREENWOOD-111',
#  'LEFFERTS BLVD',
#  'AQUEDUCT-N CNDT',
#  'AQUEDUCT TRACK',
#  'HOWARD BCH-JFK',
#  'BROAD CHANNEL',
#  'BEACH 90 ST',
#  'BEACH 98 ST',
#  'BEACH 105 ST',
#  'ROCKAWAY PK 116',
#  'BEACH 67 ST',
#  'BEACH 60 ST',
#  'BEACH 44 ST',
#  'BEACH 36 ST',
#  'BEACH 25 ST',
#  'FAR ROCKAWAY',
#  '161 ST-YANKEE',
#  '167 ST',
#  '170 ST',
#  '174-175 ST',
#  'TREMONT AVE',
#  '182-183 ST',
#  'FORDHAM ROAD',
#  'KINGSBRIDGE RD',
#  'BEDFORD PARK BL',
#  'NORWOOD-205 ST',
#  '7 AVE-53 ST',
#  '5 AVE-53 ST',
#  'LEXINGTON-53 ST',
#  'COURT SQ-23 ST',
#  'QUEENS PLAZA',
#  'STEINWAY ST',
#  '46 ST',
#  'NORTHERN BLVD',
#  '65 ST',
#  'ROOSEVELT AVE',
#  'ELMHURST AVE',
#  'GRAND AV-NEWTON',
#  '63 DR-REGO PARK',
#  '67 AVE',
#  'FOREST HILLS-71',
#  '75 AVE',
#  'UNION TPK-KEW G',
#  'VAN WYCK BLVD',
#  'SUTPHIN BLVD',
#  'PARSONS BLVD',
#  '169 ST',
#  'JAMAICA-179 ST',
#  'COURT SQ',
#  'VAN ALSTON-21ST',
#  'GREENPOINT AVE',
#  'NASSAU AV',
#  'BROADWAY',
#  'MYRTLE-WILLOUGH',
#  'BEDFORD/NOSTRAN',
#  'CLASSON AVE',
#  '47-50 ST-ROCK',
#  '42 ST-BRYANT PK',
#  '23 ST-6 AVE',
#  '14 ST-6 AVE',
#  'BROADWAY/LAFAY',
#  '2 AVE',
#  'DELANCEY ST',
#  'EAST BROADWAY',
#  'YORK ST',
#  'BERGEN ST',
#  'CARROLL ST',
#  'SMITH-9 ST',
#  '4 AVE',
#  '7 AV-PARK SLOPE',
#  '15 ST-PROSPECT',
#  'DITMAS AVE',
#  'AVE I',
#  '22 AVE-BAY PKY',
#  'AVE N',
#  'AVE P',
#  'AVE X',
#  'NEPTUNE AVE',
#  '57 ST',
#  'ROOSEVELT IS',
#  '21 ST',
#  'JAMAICA-VAN WYC',
#  'JAMAICA CENTER',
#  'ORCHARD BEACH',
#  'NEWARK HW BMEBE',
#  'HARRISON',
#  'JOURNAL SQUARE',
#  'GROVE STREET',
#  'EXCHANGE PLACE',
#  'PAVONIA/NEWPORT',
#  'CITY / BUS',
#  'PATH WTC',
#  'CHRISTOPHER ST',
#  '9TH STREET',
#  '14TH STREET',
#  'TWENTY THIRD ST',
#  'THIRTY ST',
#  'LACKAWANNA',
#  'THIRTY THIRD ST',
#  'NEWARK BM BW',
#  'NEWARK C',
#  'NEWARK HM HE',
#  'PATH WTC 2',
#  'SOUTH FERRY',
#  'WALL ST',
#  'FRANKLIN ST',
#  'HOUSTON ST',
#  '18 ST',
#  '28 ST',
#  '66 ST-LINCOLN',
#  '110 ST-CATHEDRL',
#  '116 ST-COLUMBIA',
#  '137 ST-CITY COL',
#  '157 ST',
#  '191 ST',
#  'DYCKMAN ST',
#  '207 ST',
#  '215 ST',
#  'MARBLE HILL-225',
#  '231 ST',
#  '238 ST',
#  '242 ST',
#  'BOWLING GREEN',
#  'BROOKLYN BRIDGE',
#  'BLEECKER ST',
#  'ASTOR PLACE',
#  '33 ST',
#  '42 ST-GRD CNTRL',
#  '51 ST',
#  '68ST-HUNTER COL',
#  '110 ST',
#  '138 ST-GR CONC',
#  '149 ST-GR CONC',
#  'MT EDEN AVE',
#  '176 ST',
#  'BURNSIDE AVE',
#  '183 ST',
#  'MOSHOLU PARKWAY',
#  'WOODLAWN ROAD',
#  '110 ST-CPN',
#  '148 ST-LENOX',
#  '149 ST-3 AVE',
#  'JACKSON AVE',
#  'INTERVALE-163',
#  'SIMPSON ST',
#  'FREEMAN ST',
#  '174 ST',
#  'E TREMONT AVE',
#  'E 180 ST',
#  'BRONX PARK EAST',
#  'PELHAM PARKWAY',
#  'ALLERTON AVE',
#  'BURKE AVE',
#  'GUN HILL ROAD',
#  '219 ST',
#  '225 ST',
#  '233 ST',
#  'NEREID AVE',
#  'WAKEFIELD-241',
#  '138 ST-3 AVE',
#  'BROOK AVE',
#  'CYPRESS AVE',
#  'E 143 ST',
#  'E 149 ST',
#  'LONGWOOD AVE',
#  'HUNTS POINT AVE',
#  'WHITLOCK AVE',
#  'ELDER AVE',
#  'MORRISON AVE',
#  'ST LAWRENCE AVE',
#  'E 177 ST-PARKCH',
#  'CASTLE HILL AVE',
#  'ZEREGA AVE',
#  'WESTCHESTER SQ',
#  'MIDDLETOWN ROAD',
#  'BUHRE AVE',
#  'PELHAM BAY PARK',
#  '5 AVE-BRYANT PK',
#  'VERNON/JACKSON',
#  'HUNTERS PT AVE',
#  'QUEENSBORO PLZ',
#  'BEEBE-39 AVE',
#  'WASHINGTON-36 A',
#  'BROADWAY-31 ST',
#  'GRAND-30 AVE',
#  'HOYT ST-ASTORIA',
#  'DITMARS BL-31 S',
#  '33 ST/RAWSON ST',
#  '40 ST-LOWERY ST',
#  '46 ST-BLISS ST',
#  '52 ST-LINCOLN',
#  '61 ST/WOODSIDE',
#  '69 ST-FISK AVE',
#  '74 ST-BROADWAY',
#  '82 ST-JACKSON H',
#  '90 ST-ELMHURST',
#  'JUNCTION BLVD',
#  '103 ST-CORONA',
#  'METS-WILLETS PT',
#  'MAIN ST',
#  'CLARK ST',
#  'HOYT ST',
#  'NEVINS ST',
#  'GRAND ARMY PLAZ',
#  'EASTERN PKWY',
#  'KINGSTON AVE',
#  'CROWN HTS-UTICA',
#  'SARATOGA AVE',
#  'JUNIUS ST',
#  'PENNSYLVANIA AV',
#  'PRESIDENT ST',
#  'STERLING ST',
#  'WINTHROP ST',
#  'BEVERLY ROAD',
#  'NEWKIRK AVE',
#  'FLATBUSH AVE',
#  'MORRIS PARK',
#  'BAYCHESTER AVE',
#  'DYRE AVE',
#  'ST. GEORGE',
#  'TOMPKINSVILLE',
#  'RIT-MANHATTAN',
#  'RIT-ROOSEVELT',
#  '34 ST-HUDSON YD',
#  '5 AV/59 ST',
#  '57 ST-7 AV',
#  '49 ST',
#  'TIMES SQ-42 ST',
#  '8 ST-NYU',
#  'PRINCE ST',
#  'WHITEHALL S-FRY',
#  'DELANCEY/ESSEX',
#  '7 AV',
#  'PARKSIDE AV',
#  'CHURCH AV',
#  'CORTELYOU RD',
#  'AVENUE H',
#  'AVENUE J',
#  'AVENUE M',
#  'KINGS HWY',
#  'AVENUE U',
#  'NECK RD',
#  'OCEAN PKWY',
#  'BOROUGH HALL',
#  'DEKALB AV',
#  'ATL AV-BARCLAY',
#  '4AV-9 ST',
#  'PROSPECT AV',
#  'BAY RIDGE AV',
#  '8 AV',
#  'NEW UTRECHT AV',
#  '18 AV',
#  '20 AV',
#  'BAY PKWY',
#  '9 AV',
#  '25 AV',
#  'CONEY IS-STILLW',
#  '6 AV',
#  '3 AV',
#  '1 AV',
#  'BEDFORD AV',
#  'GRAHAM AV',
#  'MONTROSE AV',
#  'MORGAN AV',
#  'MYRTLE-WYCKOFF',
#  'WILSON AV',
#  'BUSHWICK AV',
#  'ATLANTIC AV',
#  'SUTTER AV',
#  'LIVONIA AV',
#  'NEW LOTS',
#  'CANARSIE-ROCKAW',
#  'HOWARD BCH JFK',
#  'MARCY AV',
#  'FLUSHING AV',
#  'MYRTLE AV',
#  'GATES AV',
#  'ALABAMA AV',
#  'VAN SICLEN AV',
#  'NORWOOD AV',
#  '75 ST-ELDERTS',
#  '85 ST-FOREST PK',
#  'CENTRAL AV',
#  'FRESH POND RD',
#  '168 ST',
#  'CATHEDRAL PKWY',
#  '59 ST COLUMBUS',
#  '42 ST-PORT AUTH',
#  'HOYT-SCHER',
#  'LAFAYETTE AV',
#  'FRANKLIN AV',
#  'NOSTRAND AV',
#  'UTICA AV',
#  'RALPH AV',
#  'ROCKAWAY AV',
#  'BROADWAY JCT',
#  'LIBERTY AV',
#  'SHEPHERD AV',
#  'EUCLID AV',
#  'GRANT AV',
#  '80 ST',
#  '88 ST',
#  'OZONE PK LEFFRT',
#  'AQUEDUCT N.COND',
#  'AQUEDUCT RACETR',
#  'ROCKAWAY PARK B',
#  '161/YANKEE STAD',
#  '174-175 STS',
#  'TREMONT AV',
#  '182-183 STS',
#  'FORDHAM RD',
#  'BEDFORD PK BLVD',
#  'NORWOOD 205 ST',
#  '5 AV/53 ST',
#  'LEXINGTON AV/53',
#  'JKSN HT-ROOSVLT',
#  'ELMHURST AV',
#  'GRAND-NEWTOWN',
#  '67 AV',
#  'FOREST HILLS 71',
#  '75 AV',
#  'KEW GARDENS',
#  'BRIARWOOD',
#  'JAMAICA 179 ST',
#  'GREENPOINT AV',
#  'NASSAU ST',
#  'BEDFORD-NOSTRAN',
#  'CLASSON AV',
#  '47-50 STS ROCK',
#  "B'WAY-LAFAYETTE",
#  '2 AV',
#  '4 AV-9 ST',
#  'DITMAS AV',
#  'AVENUE I',
#  'AVENUE N',
#  'AVENUE P',
#  'AVENUE X',
#  'NEPTUNE AV',
#  'LEXINGTON AV/63',
#  'ROOSEVELT ISLND',
#  '21 ST-QNSBRIDGE',
#  'JAMAICA VAN WK',
#  'SUTPHIN-ARCHER',
#  '137 ST CITY COL',
#  'V.CORTLANDT PK',
#  'ASTOR PL',
#  'GRD CNTRL-42 ST',
#  '68ST-HUNTER CO',
#  '138/GRAND CONC',
#  '149/GRAND CONC',
#  'MT EDEN AV',
#  'BURNSIDE AV',
#  'MOSHOLU PKWY',
#  'WOODLAWN',
#  'CENTRAL PK N110',
#  'HARLEM 148 ST',
#  '3 AV-149 ST',
#  'JACKSON AV',
#  'INTERVALE AV',
#  'WEST FARMS SQ',
#  'PELHAM PKWY',
#  'ALLERTON AV',
#  'BURKE AV',
#  'GUN HILL RD',
#  'NEREID AV',
#  'WAKEFIELD/241',
#  '3 AV 138 ST',
#  'BROOK AV',
#  'CYPRESS AV',
#  "E 143/ST MARY'S",
#  'LONGWOOD AV',
#  'HUNTS POINT AV',
#  'WHITLOCK AV',
#  'ELDER AV',
#  'MORISN AV/SNDVW',
#  'ST LAWRENCE AV',
#  'PARKCHESTER',
#  'CASTLE HILL AV',
#  'ZEREGA AV',
#  'MIDDLETOWN RD',
#  'BUHRE AV',
#  '5 AVE',
#  'VERNON-JACKSON',
#  'HUNTERS PT AV',
#  '39 AV',
#  '36 AV',
#  '30 AV',
#  'ASTORIA BLVD',
#  'ASTORIA DITMARS',
#  '33 ST-RAWSON ST',
#  '40 ST LOWERY ST',
#  '46 ST BLISS ST',
#  '52 ST',
#  '61 ST WOODSIDE',
#  '69 ST',
#  'FLUSHING-MAIN',
#  'EASTN PKWY-MUSM',
#  'KINGSTON AV',
#  'SUTTER AV-RUTLD',
#  'NEW LOTS AV',
#  'BEVERLY RD',
#  'NEWKIRK AV',
#  'FLATBUSH AV-B.C',
#  'BAYCHESTER AV',
#  'EASTCHSTER/DYRE',
#  'PATH NEW WTC',
#  'SARATOGA AV']

# %%
def ChooseTurnstile(station):
    a = turn.loc[turn["STATION"] == station]
    return a

# %%
west4 = ChooseTurnstile('W 4 ST-WASH SQ')

# %%
west4.head()
# Out:
#        index   C/A  UNIT       SCP         STATION LINENAME DIVISION  \
# 54222  54222  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54223  54223  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54224  54224  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54225  54225  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54226  54226  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
#
#              DATE      TIME     DESC  ENTRIES  \
# 54222  06/27/2015  01:00:00  REGULAR   391165
# 54223  06/27/2015  05:00:00  REGULAR   391419
# 54224  06/27/2015  09:00:00  REGULAR   391515
# 54225  06/27/2015  13:00:00  REGULAR   391771
# 54226  06/27/2015  17:00:00  REGULAR   392243
#
#        EXITS
# 54222                                            1048373
# 54223                                            1048481
# 54224                                            1048774
# 54225                                            1049603
# 54226                                            1050670

# %%
west4Exit = west4[['index', 'C/A', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE']]

# %%
newNames = ['index', 'c/a', 'unit', 'scp', 'station', 'linename', 'division', 'date', 'time', 'desc', 'entries',
                'exits']
west4.columns = newNames

# %%
west4.head()
# Out:
#        index   c/a  unit       scp         station linename division  \
# 54222  54222  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54223  54223  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54224  54224  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54225  54225  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
# 54226  54226  N080  R138  00-00-00  W 4 ST-WASH SQ  ABCDEFM      IND
#
#              date      time     desc  entries    exits
# 54222  06/27/2015  01:00:00  REGULAR   391165  1048373
# 54223  06/27/2015  05:00:00  REGULAR   391419  1048481
# 54224  06/27/2015  09:00:00  REGULAR   391515  1048774
# 54225  06/27/2015  13:00:00  REGULAR   391771  1049603
# 54226  06/27/2015  17:00:00  REGULAR   392243  1050670

# %%
west4Exit = west4[['c/a', 'unit', 'scp', 'date', 'exits']]

# %%
west4Exit.head()
# Out:
#         c/a  unit       scp        date    exits
# 54222  N080  R138  00-00-00  06/27/2015  1048373
# 54223  N080  R138  00-00-00  06/27/2015  1048481
# 54224  N080  R138  00-00-00  06/27/2015  1048774
# 54225  N080  R138  00-00-00  06/27/2015  1049603
# 54226  N080  R138  00-00-00  06/27/2015  1050670

# %%
scp = len(west4Exit['scp'].unique())
unit = len(west4Exit['unit'].unique())
ca = len(west4Exit['c/a'].unique())
print(scp, unit, ca)
# Out:
# 19 1 2

# %%
west4Exit['corrected'] = west4Exit.groupby(['c/a','unit', 'scp', 'date'])['exits'].transform(pd.Series.diff)
west4Exit.tail()
# Out:
# /Users/thaddeusnorman/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#           c/a  unit       scp        date    exits  corrected
# 3526234  N083  R138  01-06-01  10/28/2016  4767002       35.0
# 3526235  N083  R138  01-06-01  10/28/2016  4767197      195.0
# 3526236  N083  R138  01-06-01  10/28/2016  4767675      478.0
# 3526237  N083  R138  01-06-01  10/28/2016  4767883      208.0
# 3526238  N083  R138  01-06-01  10/28/2016  4768200      317.0

# %%
w4E = west4Exit[['date', 'corrected']]
w4Edates = west4Exit['date']
w4E.head()
# Out:
#              date  corrected
# 54222  06/27/2015        NaN
# 54223  06/27/2015      108.0
# 54224  06/27/2015      293.0
# 54225  06/27/2015      829.0
# 54226  06/27/2015     1067.0

# %%
w4E_combined = w4E.groupby('date').sum()
w4E_combined.head()
# Out:
#             corrected
# date
# 06/25/2016    30084.0
# 06/26/2016    37731.0
# 06/27/2015    27105.0
# 06/27/2016    34874.0
# 06/28/2015    39305.0

# %%
w4E_combined['corrected'].plot(ylim = (0, 50000))

# %%
chambers = ChooseTurnstile('CHAMBERS ST')

# %%
chambers.head()
# Out:
#        index   C/A  UNIT       SCP      STATION LINENAME DIVISION        DATE  \
# 11100  11100  A069  R044  01-00-00  CHAMBERS ST    JZ456      BMT  06/27/2015
# 11101  11101  A069  R044  01-00-00  CHAMBERS ST    JZ456      BMT  06/27/2015
# 11102  11102  A069  R044  01-00-00  CHAMBERS ST    JZ456      BMT  06/27/2015
# 11103  11103  A069  R044  01-00-00  CHAMBERS ST    JZ456      BMT  06/27/2015
# 11104  11104  A069  R044  01-00-00  CHAMBERS ST    JZ456      BMT  06/27/2015
#
#            TIME     DESC  ENTRIES  \
# 11100  00:00:00  REGULAR  2788950
# 11101  04:00:00  REGULAR  2788958
# 11102  08:00:00  REGULAR  2788963
# 11103  12:00:00  REGULAR  2788992
# 11104  16:00:00  REGULAR  2789059
#
#        EXITS
# 11100                                           12748176
# 11101                                           12748198
# 11102                                           12748237
# 11103                                           12748328
# 11104                                           12748441

# %%
scp = len(chambers['SCP'].unique())
unit = len(chambers['UNIT'].unique())
ca = len(chambers['C/A'].unique())
print(scp, unit, ca)
# Out:
# 49 3 5
